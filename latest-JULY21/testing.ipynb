# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
file=np.load('training_data.npy',allow_pickle=True)

# %%
print(file[0])
# Out:
# [array([[ 21, 179, 181, ...,  31,  29,  28],
#        [134,  67, 177, ...,  30,  31,  28],
#        [185,  31, 114, ...,  31,  30,  30],
#        ...,
#        [ 51,  23,  57, ...,  29,  48,  17],
#        [ 30,   8,  52, ...,  11,  83,  25],
#        [ 16,  16,  17, ...,  52,  45,  54]], dtype=uint8)
#  list([0, 0, 0])]

# %%
for i in file:
    if i[1][0]==1:
        print(i)
        plt.imshow(i[0])
        break
# Out:
# [array([[176, 179,  20, ...,  26, 127,  28],
#        [137, 183, 172, ...,  32,  28,  42],
#        [ 23, 182, 121, ...,  32,  38, 192],
#        ...,
#        [ 26,   8,  13, ...,   7,  33,  35],
#        [ 19,  12,  12, ...,  45,  57,  35],
#        [ 16,  16,  17, ...,  52,  45,  54]], dtype=uint8)
#  list([1, 0, 0])]
